# %%
# %%manim -v WARNING maincalk
# from manim import *
# from math import sqrt
#
# class maincalk(Scene):
#     def construct(self):
#
#         t = Text("Całki funkcji wymiernych ", color = GOLD).scale(0.9)
#         self.play(Write(t))
#         self.wait(2)
#
#         self.play(ShrinkToCenter(t))
#         self.wait(1)
#
#
#         przyklad = MathTex(r" \int \frac{dx}{2x+3} = ").scale(0.8)
#         przyklad.shift(UP*3)
#         self.play(Write(przyklad))
#         self.wait(0.5)
#         self.play(przyklad.animate.shift(LEFT * 5))
#         self.wait(1)
#
#         table = MobjectTable([
#                 [MathTex(r"t = 2x+3")],
#                 [MathTex(r"dt = 2 dx")],
#                 [MathTex(r"\frac{dt}{2} = x dx")]
#             ],
#             include_outer_lines=False,
#             line_config={"stroke_width": 0},
#         ).scale(0.4).next_to(przyklad, RIGHT)
#
#         # Dodajemy tekst do sceny element po elemencie
#         for row in table.get_rows():
#             for element in row:
#                 self.play(Write(element), run_time=0.5)
#
#
#         # Dodajemy pionowe linie na zewnątrz tabeli
#         left_line = Line(table.get_corner(UL), table.get_corner(DL))
#         right_line = Line(table.get_corner(UR), table.get_corner(DR))
#         self.play(Create(left_line), Create(right_line))
#         self.wait(1)
#
#         przyklad2 = MathTex(r" = \int \frac{\frac{dt}{2}}{t} = ").scale(0.8).next_to(table, RIGHT)
#         self.play(Write(przyklad2))
#         self.wait(1)
#
#         przyklad2_1 = MathTex(r" = \frac{1}{2} \int \frac{dt}{t} = ").scale(0.8).next_to(table, RIGHT)
#         self.play(Transform(przyklad2, przyklad2_1))
#         self.wait(1)
#
#         przyklad2_2 = MathTex(r" = \frac{1}{2} \int \frac{dt}{t} = ").scale(0.8).next_to(table, RIGHT)
#         self.play(Transform(przyklad2, przyklad2_2))
#         self.wait(1)
#
#         przyklad3 = MathTex(r"  \frac{1}{2} \ln |t| + C").scale(0.8).next_to(przyklad2_2, RIGHT)
#         self.play(Write(przyklad3))
#         self.wait(1)
#
#         przyklad3_2 = MathTex(r"  \frac{1}{2} \ln |2x+3| + C").scale(0.8).next_to(przyklad2_2, RIGHT)
#         self.play(Transform(przyklad3, przyklad3_2))
#         self.wait(1)
#
#         self.play(FadeOut(przyklad2), run_time = 0.4)
#         self.play(FadeOut(table), run_time = 0.2)
#         self.play(FadeOut(left_line), run_time = 0.2)
#         self.play(FadeOut(right_line), run_time = 0.2)
#         self.wait(1)
#         self.play(FadeOut(przyklad3), run_time = 0.01)
#         self.play(przyklad3_2.animate.shift(LEFT * 4))
#
#         self.wait(3)
#
#
#
#
#
#
#         example = MathTex(r" \int \frac{dx}{x^2-8x+16} = ").scale(0.8)
#         example.shift(UP*2, LEFT * 5)
#         self.play(Write(example))
#         self.wait(1)
#
#
#         example2 = MathTex(r" \int \frac{dx}{(x-4)^2} =").scale(0.8)
#         example2.shift(UP*2, LEFT * 5)
#         self.play(Transform(example, example2))
#         self.wait(1)
#
#         table2 = MobjectTable([
#                 [MathTex(r"t = x-4")],
#                 [MathTex(r"dt =  dx")]
#             ],
#             include_outer_lines=False,
#             line_config={"stroke_width": 0},
#         ).scale(0.6).next_to(example, RIGHT)
#
#         # Dodajemy tekst do sceny element po elemencie
#         for row2 in table2.get_rows():
#             for element2 in row2:
#                 self.play(Write(element2), run_time=0.5)
#
#
#         # Dodajemy pionowe linie na zewnątrz tabeli
#         left_line2 = Line(table2.get_corner(UL), table2.get_corner(DL))
#         right_line2 = Line(table2.get_corner(UR), table2.get_corner(DR))
#         self.play(Create(left_line2), Create(right_line2))
#         self.wait(1)
#
#         example2 = MathTex(r" = \int \frac{dt}{t^2} = ").scale(0.8).next_to(table2, RIGHT)
#         self.play(Write(example2))
#         self.wait(1)
#
#         example3 = MathTex(r"  - \frac{1}{t^1} + C").scale(0.8).next_to(example2, RIGHT)
#         self.play(Write(example3))
#         self.wait(1)
#
#         example3_2 = MathTex(r"  -\frac{1}{3} \cdot \frac{1}{x-4} + C").scale(0.8).next_to(example2, RIGHT)
#         self.play(Transform(example3, example3_2))
#         self.wait(1)
#
#         self.play(FadeOut(example2), run_time = 0.4)
#         self.play(FadeOut(table2), run_time = 0.2)
#         self.play(FadeOut(left_line2), run_time = 0.2)
#         self.play(FadeOut(right_line2), run_time = 0.2)
#         self.wait(1.5)
#         self.play(FadeOut(example3), run_time = 0.01)
#         self.play(example3_2.animate.shift(LEFT * 4))
#         self.wait(1)
#
#
#
#
#
#         exampeho = MathTex(r" \int \frac{dx}{(7x-3)^5} = ").scale(0.8)
#         exampeho.shift(UP, LEFT * 5)
#         self.play(Write(exampeho))
#         self.wait(1)
#
#         table3 = MobjectTable([
#                 [MathTex(r"t = 7x-3")],
#                 [MathTex(r"dt = 7 \cdot dx")],
#                 [MathTex(r" \frac{dt}{7} = dx")]
#             ],
#             include_outer_lines=False,
#             line_config={"stroke_width": 0},
#         ).scale(0.3).next_to(exampeho, RIGHT)
#
#         # Dodajemy tekst do sceny element po elemencie
#         for row3 in table3.get_rows():
#             for element3 in row3:
#                 self.play(Write(element3), run_time=0.5)
#
#
#         # Dodajemy pionowe linie na zewnątrz tabeli
#         left_line3 = Line(table3.get_corner(UL), table3.get_corner(DL))
#         right_line3 = Line(table3.get_corner(UR), table3.get_corner(DR))
#         self.play(Create(left_line3), Create(right_line3))
#         self.wait(1)
#
#         exampeho2 = MathTex(r" = \int \frac{1}{7} \cdot \frac{dt}{t^5} = ").scale(0.8).next_to(table3, RIGHT)
#         self.play(Write(exampeho2))
#         self.wait(1)
#
#         exampeho3 = MathTex(r"  -\frac{1}{7} \cdot \frac{1}{4}\cdot \frac{1}{t^4} + C").scale(0.8).next_to(exampeho2, RIGHT)
#         self.play(Write(exampeho3))
#         self.wait(1)
#
#         exampeho3_2 = MathTex(r"  -\frac{1}{7} \cdot \frac{1}{4} \cdot \frac{1}{(7x-3)^4} + C").scale(0.8).next_to(exampeho2, RIGHT)
#         self.play(Transform(exampeho3, exampeho3_2))
#         self.wait(1)
#
#         self.play(FadeOut(exampeho2), run_time = 0.4)
#         self.play(FadeOut(table3), run_time = 0.2)
#         self.play(FadeOut(left_line3), run_time = 0.2)
#         self.play(FadeOut(right_line3), run_time = 0.2)
#         self.wait(1.5)
#         self.play(FadeOut(exampeho3), run_time = 0.01)
#         self.play(exampeho3_2.animate.shift(LEFT * 4))
#         self.wait(1.5)
#
#         poprawka1 = MathTex(r" \int \frac{dx}{(1 x-4)^2} =").scale(0.8)
#         poprawka1.shift(UP*2, LEFT * 5)
#         self.play(Transform(example, poprawka1))
#
#         wzor = MathTex(r" \int \frac{dx}{(ax+b)^n} = \frac{1}{a} \cdot \frac{1}{1-n} \cdot \frac{1}{(ax+b)^{n-1}}}+C").scale(0.8)
#         wzor.shift(LEFT*3, DOWN)
#         self.play(Write(wzor))
#         self.wait(2)
#
#         self.play(wzor[0][5].animate.set_color(RED), run_time = 0.2)
#         self.play(wzor[0][8].animate.set_color(GREEN), run_time = 0.2)
#         self.play(wzor[0][10].animate.set_color(YELLOW), run_time = 0.2)
#
#         self.play(poprawka1[0][5].animate.set_color(RED), run_time = 0.2)
#         self.play(poprawka1[0][7].animate.set_color(GREEN), run_time = 0.2)
#         self.play(poprawka1[0][8].animate.set_color(GREEN), run_time = 0.2)
#         self.play(poprawka1[0][10].animate.set_color(YELLOW), run_time = 0.2)
#
#         self.play(exampeho[0][5].animate.set_color(RED), run_time = 0.2)
#         self.play(exampeho[0][7].animate.set_color(GREEN), run_time = 0.2)
#         self.play(exampeho[0][8].animate.set_color(GREEN), run_time = 0.2)
#         self.play(exampeho[0][10].animate.set_color(YELLOW), run_time = 0.2)
#
#
#
#         poprawka2 = MathTex(r"    \frac{1}{1} \cdot\frac{1}{1-2} \cdot \frac{1}{(1x-4)^{2-1}} + C").scale(0.8).next_to(example2, RIGHT)
#         poprawka2.shift(LEFT*4)
#         self.play(Transform(example3_2, poprawka2))
#
#         exampeho3_3 = MathTex(r"  \frac{1}{7} \cdot \frac{1}{1-5} \cdot \frac{1}{(7x-3)^{5-1}} + C").scale(0.8).next_to(exampeho2, RIGHT)
#         exampeho3_3.shift(LEFT * 4)
#         self.play(Transform(exampeho3_2, exampeho3_3))
#         self.wait(1)
#
#         self.play(wzor[0][14].animate.set_color(RED), run_time = 0.2)
#         self.play(wzor[0][25].animate.set_color(RED), run_time = 0.2)
#         self.play(wzor[0][20].animate.set_color(YELLOW), run_time = 0.2)
#         self.play(wzor[0][30].animate.set_color(YELLOW), run_time = 0.2)
#         self.play(wzor[0][28].animate.set_color(GREEN), run_time = 0.2)
#
#         self.play(poprawka2[0][2].animate.set_color(RED), run_time = 0.2)
#         self.play(poprawka2[0][13].animate.set_color(RED), run_time = 0.2)
#         self.play(poprawka2[0][8].animate.set_color(YELLOW), run_time = 0.2)
#         self.play(poprawka2[0][15].animate.set_color(GREEN), run_time = 0.2)
#         self.play(poprawka2[0][16].animate.set_color(GREEN), run_time = 0.2)
#         self.play(poprawka2[0][18].animate.set_color(YELLOW), run_time = 0.2)
#
#         self.play(exampeho3_3[0][2].animate.set_color(RED), run_time = 0.2)
#         self.play(exampeho3_3[0][13].animate.set_color(RED), run_time = 0.2)
#         self.play(exampeho3_3[0][8].animate.set_color(YELLOW), run_time = 0.2)
#         self.play(exampeho3_3[0][15].animate.set_color(GREEN), run_time = 0.2)
#         self.play(exampeho3_3[0][16].animate.set_color(GREEN), run_time = 0.2)
#         self.play(exampeho3_3[0][18].animate.set_color(YELLOW), run_time = 0.2)
#
#         wzorplus = MathTex(r", n > 1").next_to(wzor, RIGHT).scale(0.8)
#         self.play(Create(wzorplus))
#         wzor2= MathTex(r" \int \frac{dx}{ax+b} = \frac{1}{a}\ln |ax+b| +C").next_to(wzor, DOWN).scale(0.8)
#         wzor2.shift(LEFT)
#         self.play(Create(wzor2))
#         self.wait(1)
#         wzor2plus = MathTex(r", n = 1").next_to(wzor2, RIGHT).scale(0.8)
#         self.play(Create(wzor2plus))
#
#         self.play(wzor2[0][4].animate.set_color(RED), run_time = 0.2)
#         self.play(wzor2[0][7].animate.set_color(GREEN), run_time = 0.2)
#         self.play(wzor2[0][11].animate.set_color(RED), run_time = 0.2)
#         self.play(wzor2[0][15].animate.set_color(RED), run_time = 0.2)
#         self.play(wzor2[0][18].animate.set_color(GREEN), run_time = 0.2)
#
#         self.wait(1)
#
#         self.play(przyklad[0][4].animate.set_color(RED), run_time = 0.2)
#         self.play(przyklad[0][7].animate.set_color(GREEN), run_time = 0.2)
#         self.play(przyklad3_2[0][2].animate.set_color(RED), run_time = 0.2)
#         self.play(przyklad3_2[0][6].animate.set_color(RED), run_time = 0.2)
#         self.play(przyklad3_2[0][9].animate.set_color(GREEN), run_time = 0.2)
#
#         self.wait(4)
# Out:
# <video src="media/jupyter/maincalk@2023-11-04@00-17-44.mp4" controls autoplay loop style="max-width: 60%;"  >
#       Your browser does not support the <code>video</code> element.
#     </video>

# %%
# %%manim -v WARNING prezentation1
#
# class prezentation1(Scene):
#     def construct(self):
#         ter = Text("Całki funkcji wymiernych z 1 na górze, na dole 'zwinięte':", color = GOLD).scale(0.75)
#         ter.shift(UP*3)
#         self.play(AddTextLetterByLetter(ter), run_time =1.5)
#         self.wait(2)
#         linij1= MathTex(r"n=1: \int \frac{dx}{ax+b}=\frac{1}{a}\ln |ax+b| +C ", color = GOLD).next_to(ter, DOWN).scale(0.75)
#         self.play(Create(linij1), run_time=2)
#         self.wait(1)
#
#         linij2= MathTex(r"n>1: \int \frac{dx}{(ax+b)^n}=\frac{1}{a} \cdot \frac{1}{1-n} \cdot \frac{1}{(ax+b)^{n-1}}+C ", color = GOLD).next_to(linij1, DOWN).scale(0.75)
#         linij2.shift(DOWN)
#         self.play(Create(linij2), run_time = 2)
#         self.wait(3)
# Out:
# <video src="media/jupyter/prezentation1@2023-11-04@00-26-47.mp4" controls autoplay loop style="max-width: 60%;"  >
#       Your browser does not support the <code>video</code> element.
#     </video>

# %%
# %%manim -v WARNING maincalk2
# from manim import *
# from math import sqrt
#
# class maincalk2(Scene):
#     def construct(self):
#
#         t = Text("Całki funkcji 'niezwijalnych' ", color = GOLD).scale(0.9)
#         self.play(Write(t))
#         self.wait(2)
#
#         self.play(ShrinkToCenter(t))
#         self.wait(1)
#
#         przyklad = MathTex(r" \int \frac{dx}{x^2-7x+6}").scale(0.75)
#         przyklad.shift(UP*2)
#         self.play(Write(przyklad))
#         self.wait(1)
#         self.play(przyklad.animate.shift(LEFT * 3))
#         self.wait(1)
#
#         nizej = MathTex(r" \Delta = (-7)^2 - 4 \cdot 1 \cdot 6 ").scale(0.75).next_to(przyklad, DOWN)
#         nizej2 = MathTex(r" = 25").scale(0.75).next_to(nizej, RIGHT)
#         nizej3 = MathTex(r" \sqrt{\Delta} = 5").scale(0.75).next_to(nizej, DOWN)
#
#         self.play(Write(nizej))
#         self.wait(1)
#         self.play(Write(nizej2))
#         self.wait(1)
#         self.play(Write(nizej3))
#
#         nizej4 = MathTex(r" x_{1} = \frac{7-5}{2} = 1, ").scale(0.75).next_to(nizej3, DOWN)
#         nizej5 = MathTex(r" x_{2} = \frac{7+5}{2} = 6 ").scale(0.75).next_to(nizej4, RIGHT)
#
#         self.play(Write(nizej4))
#         self.play(Write(nizej5))
#         self.wait(1)
#
#         wprawo1 = MathTex(r" =  \int \frac{dx}{(x-1)(x-6)}").scale(0.75).next_to(przyklad, RIGHT)
#         self.play(Create(wprawo1))
#         self.wait(2)
#
#
#         self.play(FadeOut(nizej5), run_time = 0.25)
#         self.play(FadeOut(nizej4), run_time = 0.25)
#         self.play(FadeOut(nizej3), run_time = 0.25)
#         self.play(FadeOut(nizej2), run_time = 0.25)
#         self.play(FadeOut(nizej), run_time = 0.25)
#
#         nowenizej = MathTex(r"\frac{1}{(x-1)(x-6)} = ").scale(0.75).next_to(przyklad, DOWN)
#         nowenizej2 = MathTex(r"\frac{A}{x-1} + \frac{B}{x-6}").scale(0.75).next_to(nowenizej, RIGHT)
#         nowenizej2_1 = MathTex(r"\frac{A(x-6)+B(x-1)}{(x-1)(x-6)}").scale(0.75).next_to(nowenizej, RIGHT)
#         self.play(Write(nowenizej))
#         self.wait(1)
#         self.play(Write(nowenizej2))
#         self.wait(1)
#         self.play(Transform(nowenizej2, nowenizej2_1))
#         self.wait(1)
#
#         jeszczenizej = MathTex(r" A(x-6)+B(x-1)  ").scale(0.75).next_to(nowenizej, DOWN)
#         jeszczenizej2 = MathTex(r"  = ").scale(0.75).next_to(jeszczenizej, RIGHT)
#         jeszczenizej3 = MathTex(r"   1").scale(0.75).next_to(jeszczenizej2, RIGHT)
#         self.play(Write(jeszczenizej), run_time = 0.3)
#         self.play(Write(jeszczenizej2), run_time = 0.3)
#         self.play(Write(jeszczenizej3), run_time = 0.3)
#         self.wait(1)
#         down = MathTex(r" Ax -6A + Bx - B").scale(0.75).next_to(nowenizej, DOWN)
#         self.play(Transform(jeszczenizej, down))
#         self.wait(1)
#         down2 = MathTex(r" x(A+B) -6A - B").scale(0.75).next_to(nowenizej, DOWN)
#         self.play(Transform(jeszczenizej, down2))
#         self.wait(1)
#         prawstr = MathTex(r"x \cdot 0 + 1").scale(0.75).next_to(jeszczenizej2, RIGHT)
#         self.play(Transform(jeszczenizej3, prawstr))
#         self.wait(1)
#         downer = MathTex(r" A + B = 0").scale(0.75).next_to(jeszczenizej, DOWN)
#         downer2 = MathTex(r" -6A - B = 1").scale(0.75).next_to(downer, RIGHT)
#         self.play(Write(downer))
#         self.play(Write(downer2))
#         self.wait(1)
#         downer_2 = MathTex(r" A  = -B").scale(0.75).next_to(jeszczenizej, DOWN)
#         self.play(Transform(downer, downer_2))
#         self.wait(1)
#         downer2_2 = MathTex(r" 5A = 1").scale(0.75).next_to(downer, RIGHT)
#         self.play(Transform(downer2, downer2_2))
#         self.wait(1.5)
#         downer2_3 = MathTex(r" A = \frac{1}{5}").scale(0.75).next_to(downer, RIGHT)
#         self.play(Transform(downer2, downer2_3))
#         self.wait(1.5)
#         downer_3 = MathTex(r" B  = -\frac{1}{5}").scale(0.75).next_to(jeszczenizej, DOWN)
#         self.play(Transform(downer, downer_3))
#         self.wait(1.5)
#
#
#         self.play(FadeOut(prawstr), run_time = 0.5)
#         self.play(FadeOut(jeszczenizej), run_time = 0.5)
#         self.play(FadeOut(jeszczenizej2), run_time = 0.5)
#         self.play(FadeOut(jeszczenizej3), run_time = 0.5)
#         self.play(FadeOut(nowenizej2), run_time = 0.5)
#         self.play(FadeOut(nowenizej), run_time = 0.5)
#         self.wait(2)
#
#         reszta = MathTex(r"= \int \frac{\frac{1}{5} \cdot dx}{x-1} + \frac{-\frac{1}{5} \cdot dx}{x-6} ").scale(0.75).next_to(przyklad, RIGHT)
#         self.play(Transform(wprawo1, reszta))
#         self.wait(2)
#         reszta_trans = MathTex(r"=   \frac{1}{5} \int \frac{dx}{x-1}  -\frac{1}{5} \int \frac{dx}{x-6} ").scale(0.75).next_to(przyklad, RIGHT)
#         self.play(Transform(wprawo1, reszta_trans))
#         self.play(FadeOut(downer), run_time = 0.5)
#         self.play(FadeOut(downer2), run_time = 0.5)
#         self.wait(1)
#         linij1= MathTex(r" \int \frac{dx}{ax+b}=\frac{1}{a}\ln |ax+b| +C ", color = GOLD).next_to(przyklad, DOWN).scale(0.75)
#         linij1.shift(DOWN+RIGHT)
#         wynik = MathTex(r"=   \frac{1}{5} \cdot \frac{1}{1} \ln |x-1| +C_{1}  -\frac{1}{5} \cdot \frac{1}{1} \ln |x-6| + C_{2} ").scale(0.75).next_to(przyklad, DOWN)
#         wynik.shift(RIGHT)
#         self.play(Create(linij1), run_time = 1)
#         self.wait(1)
#         self.play(Create(wynik), run_time = 1)
#         self.wait(1)
#         wynik2 = MathTex(r"=   \frac{1}{5}  \ln |x-1|   -\frac{1}{5}  \ln |x-6| + C ").scale(0.75).next_to(przyklad, DOWN)
#         wynik2.shift(RIGHT)
#         self.play(Transform(wynik, wynik2))
#         self.wait(3)
#
#
#
#
#         self.wait(2)
# Out:
# <video src="media/jupyter/maincalk2@2023-11-04@21-41-53.mp4" controls autoplay loop style="max-width: 60%;"  >
#       Your browser does not support the <code>video</code> element.
#     </video>

# %%
# %%manim -v WARNING maincalk3
# from manim import *
# from math import sqrt
#
# class maincalk3(Scene):
#     def construct(self):
#         przyklad = MathTex(r" \int \frac{dx}{x^2+8x+17} = ").scale(0.75)
#         przyklad.shift(UP*2)
#         self.play(Write(przyklad))
#         self.wait(1)
#         self.play(przyklad.animate.shift(LEFT * 5))
#         self.wait(1)
#
#         nizej = MathTex(r" \Delta = (8)^2 - 4 \cdot 1 \cdot 17 ").scale(0.75).next_to(przyklad, DOWN)
#         nizej2 = MathTex(r" = -4").scale(0.75).next_to(nizej, RIGHT)
#
#
#         self.play(Write(nizej))
#         self.wait(0.8)
#         self.play(Write(nizej2))
#         self.wait(2)
#
#         self.play(FadeOut(nizej2), run_time = 0.75)
#         self.play(FadeOut(nizej), run_time = 0.75)
#         self.wait(0.75)
#
#
#         wprawo1 = MathTex(r" =  \int \frac{dx}{x^2 - 8x +16 +1}").scale(0.75).next_to(przyklad, RIGHT)
#         self.play(Create(wprawo1))
#
#         wprawo2 = MathTex(r" = \int \frac{dx}{(x-4)^2 + 1 } =").scale(0.75).next_to(wprawo1, RIGHT)
#         self.play(Create(wprawo2))
#         self.wait(1)
#
#
#         table = MobjectTable([
#                 [MathTex(r"t = x-4")],
#                 [MathTex(r"dt =  dx")]
#             ],
#             include_outer_lines=False,
#             line_config={"stroke_width": 0},
#         ).scale(0.75).next_to(wprawo2, RIGHT)
#
#         for row in table.get_rows():
#             for element in row:
#                 self.play(Write(element), run_time=0.5)
#
#         left_line = Line(table.get_corner(UL), table.get_corner(DL))
#         right_line = Line(table.get_corner(UR), table.get_corner(DR))
#         self.play(Create(left_line), Create(right_line))
#         self.wait(1)
#
#         lin2 = MathTex(r" \int \frac{dt}{t^2+1} =").scale(0.75).next_to(przyklad, DOWN)
#         self.play(Create(lin2))
#         self.wait(1)
#
#         lin3_1 = MathTex(r"  \arctan t + C = ").scale(0.75).next_to(lin2, RIGHT)
#         self.play(Create(lin3_1))
#         lin4 = MathTex(r"  \arctan (x-4) + C").scale(0.75).next_to(lin3_1, RIGHT)
#         self.play(Create(lin4))
#         self.wait(1)
#
#         self.wait(4)
# Out:
# <video src="media/jupyter/maincalk3@2023-11-04@22-04-04.mp4" controls autoplay loop style="max-width: 60%;"  >
#       Your browser does not support the <code>video</code> element.
#     </video>

# %%
# %%manim -v WARNING maincalk4
# from manim import *
# from math import sqrt
#
# class maincalk4(Scene):
#     def construct(self):
#         przyklad = MathTex(r" \int \frac{dx}{2x^2+2x+1} = ").scale(0.75)
#         przyklad.shift(UP*2)
#         self.play(Write(przyklad))
#         self.wait(1)
#         self.play(przyklad.animate.shift(LEFT * 5))
#         self.wait(1)
#
#         self.play(przyklad[0][4].animate.set_color(RED), run_time = 0.5)
#         self.wait(1)
#         self.play(przyklad[0][4].animate.set_color(WHITE), run_time = 0.5)
#
#         przyklad2 = MathTex(r" \frac{1}{2} \int \frac{dx}{x^2+x+\frac{1}{2}}=").scale(0.75).next_to(przyklad, RIGHT)
#         self.play(Write(przyklad2))
#         self.wait(1)
#
#         self.play(przyklad2[0][7].animate.set_color(BLUE), run_time = 0.05)
#         self.play(przyklad2[0][8].animate.set_color(BLUE), run_time = 0.05)
#         self.play(przyklad2[0][9].animate.set_color(BLUE), run_time = 0.05)
#         self.play(przyklad2[0][10].animate.set_color(BLUE), run_time = 0.05)
#         self.play(przyklad2[0][11].animate.set_color(BLUE), run_time = 0.05)
#         self.play(przyklad2[0][12].animate.set_color(BLUE), run_time = 0.05)
#         self.play(przyklad2[0][13].animate.set_color(BLUE), run_time = 0.05)
#         self.play(przyklad2[0][14].animate.set_color(BLUE), run_time = 0.05)
#         self.wait(1)
#
#         ogolnie = MathTex(r" ax^2+bx+c").scale(0.75)
#         ogolnie.shift(LEFT*2)
#         ogolnie.set_color(BLUE)
#
#
#         self.play(Create(ogolnie))
#         self.wait(2.5)
#
#         kanon = MathTex(r" a(x-p)^2 + q").scale(0.75)
#         kanon.shift(RIGHT*2)
#         kanon.set_color(GREEN)
#
#
#         self.play(Create(kanon))
#         self.wait(2.5)
#
#         wzoryp = MathTex(r" p = -\frac{b}{2a}").scale(0.75)
#         wzoryp.shift(DOWN + LEFT*3)
#         wzoryq = MathTex(r" q = -\frac{\Delta}{4a}").scale(0.75)
#         wzoryq.shift(DOWN + RIGHT*3)
#         wzoryd = MathTex(r" \Delta = b^2 - 4ac").scale(0.75)
#         wzoryd.shift(DOWN*2 + LEFT)
#
#         przyklad2_1 = MathTex(r" \frac{1}{2} \int \frac{dx}{1x^2+1x+\frac{1}{2}} =").scale(0.75).next_to(przyklad, RIGHT)
#         self.play(Transform(przyklad2, przyklad2_1))
#         self.wait(2.5)
#
#         self.play(Write(wzoryp))
#         wzoryp2 = MathTex(r" = \frac{1}{2 \cdot 1} = \frac{1}{2}").scale(0.75).next_to(wzoryp, RIGHT)
#         self.play(Write(wzoryp2))
#         self.wait(1)
#
#         self.play(Write(wzoryq))
#         self.wait(1)
#
#
#         self.play(Write(wzoryd))
#         wzoryd2 = MathTex(r" = 1^2 - 4 \cdot 1 \cdot \frac{1}{2} = 1 - 2 = -1 ").scale(0.75).next_to(wzoryd, RIGHT)
#         self.play(Write(wzoryd2))
#         self.wait(1)
#
#         wzoryq2 = MathTex(r" = -\frac{-1}{4 \cdot 1} = \frac{1}{4}").scale(0.75).next_to(wzoryq, RIGHT)
#         self.play(Write(wzoryq2))
#         self.wait(1)
#
#
#         przyklad3 = MathTex(r" \frac{1}{2} \int \frac{dx}{(x-\frac{1}{2})^2+\frac{1}{4}}").scale(0.75).next_to(przyklad2, RIGHT)
#         self.play(Write(przyklad3))
#         self.wait(1)
#
#         self.play(przyklad3[0][7].animate.set_color(GREEN), run_time = 0.05)
#         self.play(przyklad3[0][8].animate.set_color(GREEN), run_time = 0.05)
#         self.play(przyklad3[0][9].animate.set_color(GREEN), run_time = 0.05)
#         self.play(przyklad3[0][10].animate.set_color(GREEN), run_time = 0.05)
#         self.play(przyklad3[0][11].animate.set_color(GREEN), run_time = 0.05)
#         self.play(przyklad3[0][12].animate.set_color(GREEN), run_time = 0.05)
#         self.play(przyklad3[0][13].animate.set_color(GREEN), run_time = 0.05)
#         self.play(przyklad3[0][14].animate.set_color(GREEN), run_time = 0.05)
#         self.play(przyklad3[0][15].animate.set_color(GREEN), run_time = 0.05)
#         self.play(przyklad3[0][16].animate.set_color(GREEN), run_time = 0.05)
#         self.play(przyklad3[0][17].animate.set_color(GREEN), run_time = 0.05)
#         self.play(przyklad3[0][18].animate.set_color(GREEN), run_time = 0.05)
#
#
#
#
#         self.play(FadeOut(wzoryd2), run_time = 0.5)
#         self.play(FadeOut(wzoryd), run_time = 0.5)
#         self.play(FadeOut(wzoryq2), run_time = 0.5)
#         self.play(FadeOut(wzoryq), run_time = 0.5)
#         self.play(FadeOut(wzoryp2), run_time = 0.5)
#         self.play(FadeOut(wzoryp), run_time = 0.5)
#         self.play(FadeOut(ogolnie), run_time = 0.5)
#         self.play(FadeOut(kanon), run_time = 0.5)
#
#         przykladkt = MathTex(r" = \frac{1}{2} \int \frac{dx}{\frac{1}{4} \cdot [4 \cdot (x-\frac{1}{2})^2 + 1]}").scale(0.75).next_to(przyklad, DOWN)
#         przykladkt.shift(RIGHT*0.25)
#         self.play(Write(przykladkt))
#         self.wait(2)
#
#         przykladkt2 = MathTex(r" = \frac{1}{2} \cdot ").scale(0.75).next_to(przykladkt, RIGHT)
#         self.play(Write(przykladkt2))
#
#         przykladkt3 = MathTex(r" \frac{1}{\frac{1}{4}} ").scale(0.75).next_to(przykladkt2, RIGHT)
#         self.play(Write(przykladkt3))
#
#         przykladkt4 = MathTex(r"  \int \frac{dx}{ 2^2 \cdot (x-\frac{1}{2})^2 + 1} ").scale(0.75).next_to(przykladkt3, RIGHT)
#         self.play(Write(przykladkt4))
#
#         przykladkt33 = MathTex(r"  4 ").scale(0.75).next_to(przykladkt2, RIGHT)
#         self.play(Transform(przykladkt3, przykladkt33))
#
#         przykladkt44 = MathTex(r"  \int \frac{dx}{(2x-1)^2 + 1}= ").scale(0.75).next_to(przykladkt3, RIGHT)
#         self.play(Transform(przykladkt4, przykladkt44))
#
#
#         table = MobjectTable([
#                 [MathTex(r"t = 2x-1")],
#                 [MathTex(r"dt =  2 dx")],
#                 [MathTex(r"\frac{dt}{2} = dx")]
#             ],
#             include_outer_lines=False,
#             line_config={"stroke_width": 0},
#         ).scale(0.4).next_to(przykladkt44, RIGHT)
#
#         for row in table.get_rows():
#             for element in row:
#                 self.play(Write(element), run_time=0.5)
#
#         left_line = Line(table.get_corner(UL), table.get_corner(DL))
#         right_line = Line(table.get_corner(UR), table.get_corner(DR))
#         self.play(Create(left_line), Create(right_line))
#         self.wait(1)
#
#         przyklad5 = MathTex(r"= 2 \int \frac{\frac{dt}{2}}{t^2+1} ").scale(0.75).next_to(przykladkt, DOWN)
#         self.play(Write(przyklad5))
#         self.wait(1)
#
#         przyklad55 = MathTex(r" = \int \frac{dt}{t^2+1} ").scale(0.75).next_to(przykladkt, DOWN)
#         self.play(Transform(przyklad5, przyklad55))
#         self.wait(1)
#
#         przyklad6 = MathTex(r" = \arctan t + C").scale(0.75).next_to(przyklad55, RIGHT)
#         self.play(Write(przyklad6))
#         self.wait(1)
#
#         przyklad7 = MathTex(r" = \arctan (2x-1) + C").scale(0.75).next_to(przyklad6, RIGHT)
#         self.play(Write(przyklad7))
#         self.wait(1)
#
#         self.wait(2)
# Out:
# <video src="media/jupyter/maincalk4@2023-11-04@23-26-37.mp4" controls autoplay loop style="max-width: 60%;"  >
#       Your browser does not support the <code>video</code> element.
#     </video>

# %%
# %%manim -v WARNING prezentation2
#
# class prezentation2(Scene):
#     def construct(self):
#         ter = Text("Całki funkcji wymiernych z 1 na górze na dole 'niezwinięte':", color = GOLD).scale(0.6)
#         ter.shift(UP*3)
#         self.play(AddTextLetterByLetter(ter))
#         self.wait(2)
#         linij1= MathTex(r"\Delta>0: \int \frac{dx}{ax^2+bx+c}", color = GOLD).next_to(ter, DOWN).scale(0.6)
#         linij1.shift(LEFT*4.5)
#         self.play(Create(linij1), run_time=2)
#         self.wait(1)
#         linij11= MathTex(r"= \int \frac{dx}{a(x-x_{1})(x-x_{2})} ", color = GOLD).next_to(linij1, RIGHT).scale(0.6)
#         linij11.shift(LEFT)
#         self.play(Create(linij11), run_time=1.5)
#         self.wait(1)
#         linij111= MathTex(r"= \int \frac{A}{(x-x_{1})} dx+ \int \frac{B}{(x-x_{2})} dx ", color = GOLD).next_to(linij1, RIGHT).scale(0.6)
#         linij111.shift(LEFT)
#         self.play(Transform(linij11, linij111), run_time=1.5)
#         self.wait(1)
#         linij1111= MathTex(r"= A \ln|x-x{1}| + B \ln|x-x_{2}| + C ", color = GOLD).next_to(linij1, RIGHT).scale(0.6)
#         linij1111.shift(LEFT)
#         self.play(Transform(linij11, linij111), run_time=1.5)
#         self.wait(1)
#
#         linij2= MathTex(r"\Delta < 0: \int \frac{dx}{(x-p)^2 + q }", color = GOLD).next_to(linij1, DOWN).scale(0.6)
#         linij2.shift(DOWN*0.75)
#         self.play(Create(linij2), run_time = 2)
#
#         linij22= MathTex(r"= \int \frac{dx}{q \cdot [\frac{(x-p)^2}{q}] + 1}", color = GOLD).next_to(linij2, RIGHT).scale(0.6)
#         linij22.shift(LEFT)
#         self.play(Create(linij22), run_time=1.5)
#         self.wait(1)
#
#         linij222= MathTex(r"=\frac{1}{q} \int \frac{dx}{(\frac{(x-p)}{\sqrt{q}})^2 + 1}=", color = GOLD).next_to(linij2, RIGHT).scale(0.6)
#         linij222.shift(LEFT)
#         self.play(Transform(linij22, linij222), run_time=1.5)
#         self.wait(1)
#
#
#
#         table = MobjectTable([
#                 [MathTex(r"t = \frac{x-p}{\sqrt{q}}", color = GOLD)],
#                 [MathTex(r"dt =   dx", color = GOLD)]
#             ],
#             include_outer_lines=False,
#             line_config={"stroke_width": 0},
#         ).scale(0.6).next_to(linij22, RIGHT)
#
#         for row in table.get_rows():
#             for element in row:
#                 self.play(Write(element), run_time=0.5)
#
#         left_line = Line(table.get_corner(UL), table.get_corner(DL), color = GOLD)
#         right_line = Line(table.get_corner(UR), table.get_corner(DR), color = GOLD)
#         self.play(Create(left_line), Create(right_line))
#         self.wait(1)
#
#         linij2pq= MathTex(r"= \frac{1}{q} \int \frac{dt}{t^2 + 1}  ", color = GOLD).next_to(table, RIGHT).scale(0.6)
#         linij2pq.shift(LEFT*0.3)
#         self.play(Create(linij2pq), run_time=1.5)
#         self.wait(1)
#
#         linij22pq= MathTex(r"= \frac{1}{q} \arctan(t) + C  ", color = GOLD).next_to(table, RIGHT).scale(0.6)
#         linij22pq.shift(LEFT*0.3)
#         self.play(Transform(linij2pq, linij22pq), run_time=1.5)
#         self.wait(1)
#
#         linij222pq= MathTex(r"= \frac{1}{q} \arctan(\frac{x-p}{\sqrt{q}}) + C  ", color = GOLD).next_to(table, RIGHT).scale(0.6)
#         linij222pq.shift(LEFT*0.45)
#         self.play(Transform(linij2pq, linij222pq), run_time=1.5)
#         self.wait(1)
#
#         self.play(FadeOut(right_line), run_time=0.1)
#         self.play(FadeOut(table), run_time=0.1)
#         self.play(FadeOut(left_line), run_time=0.1)
#         self.play(FadeOut(linij22), run_time=0.1)
#
#         self.play(linij2pq.animate.shift(LEFT * 5))
#
#
#         self.wait(3)
# Out:
# <video src="media/jupyter/prezentation2@2023-11-04@23-31-36.mp4" controls autoplay loop style="max-width: 60%;"  >
#       Your browser does not support the <code>video</code> element.
#     </video>

# %%
# %%manim -v WARNING lecimyy
#
# class lecimyy(Scene):
#     def construct(self):
#
#
#         przyklad1 = MathTex(r"1. \int \frac{2x+3}{x^2+8x+16} dx").scale(0.7)
#         przyklad1.shift(UP + LEFT*2)
#         self.play(Write(przyklad1))
#         self.wait(2)
#
#         przyklad11 = MathTex(r" =  \int \frac{2x+3}{(x+4)^2} dx").scale(0.7).next_to(przyklad1, RIGHT)
#         self.play(Write(przyklad11))
#         self.wait(1)
#
#         przyklad1d = MathTex(r",  \Delta = 0").scale(0.7).next_to(przyklad11, RIGHT)
#         self.play(Write(przyklad1d))
#         self.wait(1)
#
#
#         przyklad2 = MathTex(r"2.  \int \frac{2x+3}{x^2+5x+4} dx").scale(0.7)
#         przyklad2.shift( LEFT*2)
#         self.play(Write(przyklad2))
#         self.wait(2)
#
#         przyklad22 = MathTex(r" =  \int \frac{2x+3}{(x+1)(x+4)} dx").scale(0.7).next_to(przyklad2, RIGHT)
#         self.play(Write(przyklad22))
#         self.wait(1)
#
#         przyklad2d = MathTex(r", \Delta > 0").scale(0.7).next_to(przyklad22, RIGHT)
#         self.play(Write(przyklad2d))
#         self.wait(1)
#
#         przyklad3 = MathTex(r"3. \int \frac{2x+3}{x^2+5x+7} dx").scale(0.7)
#         przyklad3.shift(DOWN*1.5 + LEFT*2)
#         self.play(Write(przyklad3))
#         self.wait(2)
#
#         self.play(przyklad3.animate.set_color(RED), run_time = 0.3)
#
#         przyklad3d = MathTex(r", \Delta < 0").scale(0.7).next_to(przyklad3, RIGHT)
#         self.play(Write(przyklad3d))
#         self.wait(1)
#
#
#         self.wait(2)
# Out:
# <video src="media/jupyter/lecimyy@2023-11-05@08-05-48.mp4" controls autoplay loop style="max-width: 60%;"  >
#       Your browser does not support the <code>video</code> element.
#     </video>

# %%
# %%manim -v WARNING leciim
#
# class leciim(Scene):
#     def construct(self):
#
#
#         przyklad1 = MathTex(r" \int \frac{2x+3}{x^2+8x+16} dx").scale(0.7)
#         przyklad1.shift(UP*3 + LEFT*3)
#         self.play(Write(przyklad1))
#         self.wait(2)
#
#         przyklad1cd = MathTex(r" = \int \frac{2x+3}{(x+4)^2} dx ").scale(0.7).next_to(przyklad1, RIGHT)
#         self.play(Write(przyklad1cd))
#         self.wait(2)
#
#         popr = MathTex(r" \frac{2x+3}{(x+4)^2} =").scale(0.7)
#         popr.shift(LEFT*3)
#         self.play(Write(popr))
#         self.wait(2)
#
#         popr2 = MathTex(r"\frac{A}{x+4} + \frac{B}{(x+4)^2}=").scale(0.7).next_to(popr, RIGHT)
#         self.play(Write(popr2))
#         self.wait(2)
#
#         popr21 = MathTex(r"\frac{A \cdot (x+4)}{(x+4)^2} + \frac{B}{(x+4)^2}").scale(0.7).next_to(popr2, RIGHT)
#         self.play(Create(popr21))
#         self.wait(2)
#
#         popr22 = MathTex(r"\frac{A \cdot (x+4) + B }{(x+4)^2}").scale(0.7).next_to(popr2, RIGHT)
#         self.play(Transform(popr21, popr22))
#         self.wait(2)
#
#         popr23 = MathTex(r"\frac{Ax+4A+B}{(x+4)^2}").scale(0.7).next_to(popr2, RIGHT)
#         popr23.shift(RIGHT*0.2)
#         self.play(Transform(popr21, popr23))
#         self.wait(1)
#
#         nizej = MathTex(r" A=2").scale(0.7).next_to(popr, DOWN)
#         self.play(Write(nizej))
#         self.wait(2)
#
#
#         nizej2 = MathTex(r" 4A+B=3").scale(0.7).next_to(nizej, DOWN)
#         self.play(Write(nizej2))
#         self.wait(2)
#
#         nizej22 = MathTex(r" B = 3-4A").scale(0.7).next_to(nizej, DOWN)
#         self.play(Transform(nizej2, nizej22))
#         self.wait(1)
#
#         nizej222 = MathTex(r" B = 3-8").scale(0.7).next_to(nizej, DOWN)
#         self.play(Transform(nizej2, nizej222))
#         self.wait(1)
#
#         nizej2222 = MathTex(r" B = -5").scale(0.7).next_to(nizej, DOWN)
#         self.play(Transform(nizej2, nizej2222))
#         self.wait(1)
#
#         abc = MathTex(r"= \int \frac{2}{x+4} dx - \int \frac{5}{(x+4)^2} dx").scale(0.7).next_to(przyklad1cd, RIGHT)
#         self.play(Write(abc))
#         self.wait(2)
#
#         self.play(FadeOut(nizej2), run_time = 0.3)
#         self.play(FadeOut(nizej), run_time = 0.3)
#         self.play(FadeOut(popr21), run_time = 0.3)
#         self.play(FadeOut(popr2), run_time = 0.3)
#         self.play(FadeOut(popr), run_time = 0.3)
#
#         abc2 = MathTex(r"= 2 \int \frac{dx}{x+4} - 5\int \frac{dx}{(x+4)^2}").scale(0.7).next_to(przyklad1cd, RIGHT)
#         self.play(Transform(abc, abc2))
#         self.wait(2)
#
#
#
#         linij1= MathTex(r" \int \frac{dx}{ax+b} = \frac{1}{a}\ln |ax+b| +C ", color = GOLD).scale(0.75)
#         linij1.shift(LEFT *3)
#         self.play(Create(linij1), run_time = 1)
#         self.wait(2)
#
#         linij2= MathTex(r"\int \frac{dx}{(ax+b)^n} = \frac{1}{a} \cdot \frac{1}{1-n} \cdot \frac{1}{(ax+b)^{n-1}}+C ", color = GOLD).scale(0.75)
#         linij2.shift(DOWN+LEFT*3)
#         self.play(Create(linij2), run_time = 1)
#         self.wait(2)
#
#         linij22= MathTex(r"\int \frac{dx}{(ax+b)^2} = \frac{1}{a} \cdot \frac{1}{1-2} \cdot \frac{1}{(ax+b)^{2-1}}+C ", color = GOLD).scale(0.75)
#         linij22.shift(DOWN+LEFT)
#         self.play(Transform(linij2, linij22), run_time = 1)
#         self.wait(2)
#
#         linij222= MathTex(r"\int \frac{dx}{(ax+b)^2} = - \frac{1}{a} \cdot \frac{1}{ax+b}+C ", color = GOLD).scale(0.75)
#         linij222.shift(DOWN+LEFT*2)
#         self.play(Transform(linij2, linij222), run_time = 1)
#         self.wait(2)
#
#
#         dalejlecimy = MathTex(r"= 2 \ln|x+4| + \frac{5}{x+4} + C ").scale(0.75).next_to(przyklad1, DOWN)
#         self.play(Write(dalejlecimy))
#         self.wait(2)
#
#
#
#         self.wait(3)
# Out:
# <video src="media/jupyter/leciim@2023-10-19@12-07-17.mp4" controls autoplay loop style="max-width: 60%;"  >
#       Your browser does not support the <code>video</code> element.
#     </video>

# %%
# %%manim -v WARNING leciimdur
#
# class leciimdur(Scene):
#     def construct(self):
#
#
#         przyklad1 = MathTex(r" \int \frac{2x+3}{x^2+5x+4} dx").scale(0.7)
#         przyklad1.shift(UP*3 + LEFT*3)
#         self.play(Write(przyklad1))
#         self.wait(2)
#
#         przyklad12 = MathTex(r"= \int \frac{2x+3}{(x+1)(x+4)}").scale(0.7).next_to(przyklad1, RIGHT)
#         self.play(Write(przyklad12))
#         self.wait(1)
#
#         popr = MathTex(r" \frac{2x+3}{(x+1)(x+4)} =").scale(0.7)
#         popr.shift(LEFT*3)
#         self.play(Write(popr))
#         self.wait(2)
#
#         popr2 = MathTex(r"\frac{A}{x+4} + \frac{B}{x+1}=").scale(0.7).next_to(popr, RIGHT)
#         self.play(Write(popr2))
#         self.wait(2)
#
#         popr21 = MathTex(r"\frac{A \cdot (x+1)}{(x+1)(x+4)} + \frac{B \cdot (x+4)}{(x+1)(x+4)}").scale(0.7).next_to(popr2, RIGHT)
#         self.play(Write(popr21))
#         self.wait(2)
#
#         popr22 = MathTex(r"\frac{A \cdot (x+1) + B \cdot (x+4) }{(x+1)(x+4)}").scale(0.7).next_to(popr2, RIGHT)
#         self.play(Transform(popr21, popr22))
#         self.wait(2)
#
#         popr23 = MathTex(r"\frac{x(A+B)+A+4B}{(x+1)(x+4)}").scale(0.7).next_to(popr2, RIGHT)
#         popr23.shift(RIGHT*0.2)
#         self.play(Transform(popr21, popr23))
#         self.wait(1)
#
#         nizej = MathTex(r" A+B=2").scale(0.7).next_to(popr, DOWN)
#         self.play(Write(nizej))
#         self.wait(2)
#
#
#         nizej2 = MathTex(r" A+4B=3").scale(0.7).next_to(nizej, DOWN)
#         self.play(Write(nizej2))
#         self.wait(2)
#
#         nizej22 = MathTex(r" A = 3-4B").scale(0.7).next_to(nizej, DOWN)
#         self.play(Transform(nizej2, nizej22))
#         self.wait(1)
#
#         nizej11 = MathTex(r" 3-4B+B=2").scale(0.7).next_to(popr, DOWN)
#         self.play(Transform(nizej, nizej11))
#         self.wait(1)
#
#         nizej111 = MathTex(r" -3B=-1").scale(0.7).next_to(popr, DOWN)
#         self.play(Transform(nizej, nizej111))
#         self.wait(1)
#
#         nizej1111 = MathTex(r" B=\frac{1}{3}").scale(0.7).next_to(popr, DOWN)
#         self.play(Transform(nizej, nizej1111))
#         self.wait(1)
#
#         nizej222 = MathTex(r" A = \frac{5}{3}").scale(0.7).next_to(nizej, DOWN)
#         self.play(Transform(nizej2, nizej222))
#         self.wait(1)
#
#         przyklad13 = MathTex(r"= \int \frac{\frac{5}{3}}{(x+4)} dx + \int \frac{\frac{1}{3}}{(x+1)} dx").scale(0.7).next_to(przyklad12, RIGHT)
#         self.play(Write(przyklad13))
#         self.wait(1)
#
#         przyklad14 = MathTex(r"= \frac{5}{3} \int \frac{dx}{(x+4)} + \frac{1}{3} \int \frac{dx}{(x+1)}").scale(0.7).next_to(przyklad12, RIGHT)
#         self.play(Transform(przyklad13, przyklad14))
#         self.wait(1)
#
#         self.play(FadeOut(nizej2), run_time = 0.3)
#         self.play(FadeOut(nizej), run_time = 0.3)
#         self.play(FadeOut(popr21), run_time = 0.3)
#         self.play(FadeOut(popr2), run_time = 0.3)
#         self.play(FadeOut(popr), run_time = 0.3)
#
#         linij1= MathTex(r" \int \frac{dx}{ax+b} = \frac{1}{a}\ln |ax+b| +C ", color = GOLD).scale(0.75)
#         linij1.shift(LEFT *3)
#         self.play(Create(linij1), run_time = 1)
#         self.wait(2)
#
#         dalejlecimy = MathTex(r"= \frac{5}{3} \ln|x+4|  + \frac{1}{3} \ln|x+1| + C ").scale(0.75).next_to(przyklad1, DOWN)
#         self.play(Write(dalejlecimy))
#         self.wait(5)
# Out:
# <video src="media/jupyter/leciimdur@2023-11-05@08-12-43.mp4" controls autoplay loop style="max-width: 60%;"  >
#       Your browser does not support the <code>video</code> element.
#     </video>

# %%
# %%manim -v WARNING leciimdura
#
# class leciimdura(Scene):
#     def construct(self):
#
#
#         przyklad1 = MathTex(r" \int \frac{2x+3}{x^2+5x+7} dx").scale(0.7)
#         przyklad1.shift(UP*3 + LEFT*4)
#         self.play(Write(przyklad1))
#         self.wait(3)
#
#         nadole = MathTex(r" (x^2+5x+7)' = 2x + 5").scale(0.7)
#         nadole.shift(DOWN)
#         self.play(Write(nadole))
#
#         przyklad12 = MathTex(r"= \int \frac{2x+5 - 2}{x^2+5x+7} dx").scale(0.7).next_to(przyklad1)
#         self.play(Write(przyklad12), run_time=2)
#         self.wait(3)
#
#         self.play(FadeOut(nadole))
#
#         przyklad13 = MathTex(r"= \int \frac{2x+5}{x^2+5x+7} dx + \int \frac{-2}{x^2+5x+7} dx").scale(0.7).next_to(przyklad12)
#         self.play(Write(przyklad13))
#         self.wait(2)
#
#         nadolewzor = MathTex(r" \int \frac{f'(x)}{f(x)} dx = ln|f(x)| + C ", color=GOLD).scale(0.7)
#         self.play(Write(nadolewzor))
#         self.wait(2)
#
#         przyklad14 = MathTex(r"= \ln|x^2+5x+7| + C ").scale(0.7).next_to(przyklad1, DOWN)
#         przyklad14.shift(RIGHT+DOWN)
#         self.play(Write(przyklad14))
#         self.wait(2)
#
#         self.play(FadeOut(nadolewzor))
#         self.wait(2)
#
#         p = MathTex(r"p = - \frac{5}{2}").scale(0.7)
#         p.shift(LEFT*2)
#         self.play(Write(p))
#         self.wait(1)
#
#         q = MathTex(r"q =  \frac{3}{4}").scale(0.7)
#         q.shift(RIGHT*2)
#         self.play(Write(q))
#         self.wait(1)
#
#
#         przyklad15 = MathTex(r"  -2 \int \frac{dx}{(x+\frac{5}{2})^2 + \frac{3}{2} }").scale(0.7).next_to(przyklad14, RIGHT)
#         self.play(Write(przyklad15))
#         self.wait(1)
#
#
#         self.play(FadeOut(p))
#         self.play(FadeOut(q))
#         self.wait(2)
#
#         wzoreczek = MathTex(r"\int \frac{dx}{(x-p)^2 + q} = \frac{1}{q} \arctan(\frac{x-p}{\sqrt{q}}) + C", color = GOLD).scale(0.7)
#         self.play(Write(wzoreczek))
#         self.wait(2)
#
#
#         przyklad155 = MathTex(r"  -2 \cdot \frac{1}{\frac{3}{2}} \arctan(\frac{x+\frac{5}{2}}{\sqrt{\frac{3}{4}}})").scale(0.7).next_to(przyklad14, RIGHT)
#         self.play(Transform(przyklad15, przyklad155))
#         self.wait(1)
#
#         przyklad1555 = MathTex(r"  - \frac{4}{3} \arctan(\frac{x+\frac{5}{2}}{\sqrt{\frac{3}{4}}})").scale(0.7).next_to(przyklad14, RIGHT)
#         self.play(Transform(przyklad15, przyklad1555))
#         self.wait(6)
# Out:
# Animation 0: Write(MathTex(' \\int \\frac{2x+3}{x^2+5x+7} dx')):   0%|          | 0/120 [00:00<?, ?it/s]
# <video src="media/jupyter/leciimdura@2023-11-05@08-16-03.mp4" controls autoplay loop style="max-width: 60%;"  >
#       Your browser does not support the <code>video</code> element.
#     </video>

# %%
# %%manim -v WARNING prezentation3
#
# class prezentation3(Scene):
#     def construct(self):
#         ter = Text("Całki funkcji wymiernych z wyrazeniem na górze:", color = GOLD).scale(0.6)
#         ter.shift(UP*3)
#         self.play(AddTextLetterByLetter(ter), run_time=0.75)
#         self.wait(2)
#         linij1= MathTex(r"\Delta>0: \int \frac{a_{2}x+b_{2}}{ax^2+bx+c} dx = ", color = GOLD).next_to(ter, DOWN).scale(0.6)
#         linij1.shift(LEFT*4.5)
#         self.play(Create(linij1), run_time=2)
#         self.wait(1)
#         linij11= MathTex(r"= \int \frac{a_{2}x+b_{2}}{a(x-x_{1})(x-x_{2}) dx} ", color = GOLD).next_to(linij1, RIGHT).scale(0.6)
#         linij11.shift(LEFT)
#         self.play(Create(linij11), run_time=1.5)
#         self.wait(1)
#         linij111= MathTex(r"= \int \frac{A}{(x-x_{1})} dx+ \int \frac{B}{(x-x_{2})} dx ", color = GOLD).next_to(linij1, RIGHT).scale(0.6)
#         linij111.shift(LEFT)
#         self.play(Transform(linij11, linij111), run_time=1.5)
#         self.wait(1)
#         linij1111= MathTex(r"= A \ln|x-x_{1}| + B \ln|x-x_{2}| + C ", color = GOLD).next_to(linij1, RIGHT).scale(0.6)
#         linij1111.shift(LEFT)
#         self.play(Transform(linij11, linij1111), run_time=1.5)
#         self.wait(1)
#
#
#         linij3= MathTex(r"\Delta=0: \int \frac{a_{2}x+b_{2}}{(x-x_{0})^2} dx = ", color = GOLD).next_to(linij1, DOWN).scale(0.6)
#         self.play(Create(linij3), run_time=2)
#         self.wait(1)
#         linij33= MathTex(r"= \int \frac{A}{(x-x_{0})} dx+ \int \frac{B}{(x-x_{0})^2} dx ", color = GOLD).next_to(linij3, RIGHT).scale(0.6)
#         linij33.shift(LEFT)
#         self.play(Create(linij33), run_time=1.5)
#         self.wait(1)
#         linij333= MathTex(r"= \ln|x-x_{0}| - \frac{1}{x-x_{0}}+ C ", color = GOLD).next_to(linij3, RIGHT).scale(0.6)
#         linij333.shift(LEFT)
#         self.play(Transform(linij33, linij333), run_time=1.5)
#         self.wait(1)
#
#         linij2= MathTex(r"\Delta < 0: \int \frac{a_{2}x+b_{2}}{ax^2+bx+c} dx", color = GOLD).next_to(linij3, DOWN).scale(0.6)
#         self.play(Create(linij2), run_time = 2)
#
#         linij22= MathTex(r"= \int \frac{(ax^2+bx+c)'+A}{ax^2+bx+c} dx", color = GOLD).next_to(linij2, RIGHT).scale(0.6)
#         linij22.shift(LEFT)
#         self.play(Create(linij22), run_time=1.5)
#         self.wait(1)
#
#         linij222= MathTex(r"=\int \frac{(ax^2+bx+c)'}{ax^2+bx+c} + \int \frac{A}{ax^2+bx+c} dx", color = GOLD).next_to(linij2, RIGHT).scale(0.6)
#         linij222.shift(LEFT)
#         self.play(Transform(linij22, linij222), run_time=1.5)
#         self.wait(1)
#
#         linij222= MathTex(r"=\ln|ax^2+bx+c| + \frac{1}{q} \arctan(\frac{x-p}{\sqrt{q}}) + C ", color = GOLD).next_to(linij2, RIGHT).scale(0.6)
#         linij222.shift(LEFT)
#         self.play(Transform(linij22, linij222), run_time=1.5)
#         self.wait(1)
#
#
#         self.wait(5)
# Out:
# <video src="media/jupyter/prezentation3@2023-11-05@09-24-22.mp4" controls autoplay loop style="max-width: 60%;"  >
#       Your browser does not support the <code>video</code> element.
#     </video>

# %%
# %%manim -v WARNING tojeszczeniekoniec
#
# class tojeszczeniekoniec(Scene):
#     def construct(self):
#
#         przyklad1 = MathTex(r" \int \frac{2x-1}{(x^2+3)(x-3)} dx").scale(0.7)
#         przyklad1.shift(UP*3 + LEFT*4)
#         self.play(Write(przyklad1))
#         self.wait(2)
#
#         przyklad12= MathTex(r"  \frac{2x-1}{(x^2+3)(x-3)}").scale(0.7)
#         przyklad12.shift(LEFT*4 + UP)
#         self.play(Write(przyklad12))
#         self.wait(2)
#
#         przyklad123= MathTex(r"  =\frac{Ax+B}{x^2+3} + \frac{C}{x-3}").scale(0.7).next_to(przyklad12, RIGHT)
#         self.play(Write(przyklad123))
#         self.wait(2)
#
#         przyklad1234= MathTex(r"  =\frac{(Ax+B) \cdot (x-3)}{x^2+3} + \frac{C \cdot (x^2+3)}{x-3}").scale(0.7).next_to(przyklad12, RIGHT)
#         self.play(Transform(przyklad123, przyklad1234))
#         self.wait(2)
#
#         przyklad12345 = MathTex(r"  =\frac{Ax^2-3Ax+Bx-3B}{x^2+3} + \frac{Cx^2 +3C }{x-3}").scale(0.7).next_to(przyklad12, RIGHT)
#         self.play(Transform(przyklad123, przyklad12345))
#         self.wait(2)
#
#         przyklad123456 = MathTex(r" =\frac{x^2(A+C) + x(-3A+B) -3B + 3C}{(x^2-3)(x-3)}").scale(0.7).next_to(przyklad12, RIGHT)
#         self.play(Transform(przyklad123, przyklad123456))
#         self.wait(1)
#
#         nisko = MathTex(r" A+C = 0").scale(0.7)
#         nisko.shift(LEFT*5)
#         self.play(Write(nisko))
#         self.wait(1)
#
#         nisko2 = MathTex(r" -3A + B = 0").scale(0.7).next_to(nisko, DOWN)
#         nisko2.shift(DOWN*0.5)
#         self.play(Write(nisko2))
#         self.wait(1)
#
#         nisko3 = MathTex(r" -3B + 3C = -1").scale(0.7).next_to(nisko2, DOWN)
#         nisko3.shift(DOWN*0.5)
#         self.play(Write(nisko3))
#         self.wait(1)
#
#         niskox = MathTex(r" C = -A").scale(0.7)
#         niskox.shift(LEFT*5)
#         self.play(Transform(nisko, niskox))
#         self.wait(1)
#
#         nisko3x = MathTex(r" -3B - 3A = -1").scale(0.7).next_to(nisko2, DOWN)
#         nisko3x.shift(DOWN*0.5)
#         self.play(Transform(nisko3, nisko3x))
#         self.wait(1)
#
#         nisko2x = MathTex(r" B= 2+3A").scale(0.7).next_to(nisko, DOWN)
#         nisko2x.shift(DOWN*0.5)
#         self.play(Transform(nisko2, nisko2x))
#         self.wait(1)
#
#         nisko3xx = MathTex(r" -3(2+3A) - 3A = -1").scale(0.7).next_to(nisko2, DOWN)
#         nisko3xx.shift(DOWN*0.5)
#         self.play(Transform(nisko3, nisko3xx))
#         self.wait(0.7)
#
#         nisko3xxx = MathTex(r" -6 -9A - 3A = -1").scale(0.7).next_to(nisko2, DOWN)
#         nisko3xxx.shift(DOWN*0.5)
#         self.play(Transform(nisko3, nisko3xxx))
#         self.wait(0.7)
#
#         nisko3xxxx = MathTex(r" -12A = 5").scale(0.7).next_to(nisko2, DOWN)
#         nisko3xxxx.shift(DOWN*0.5)
#         self.play(Transform(nisko3, nisko3xxxx))
#         self.wait(0.7)
#
#         nisko3xxxxx = MathTex(r" A = -\frac{5}{12}").scale(0.7).next_to(nisko2, DOWN)
#         nisko3xxxxx.shift(DOWN*0.5)
#         self.play(Transform(nisko3, nisko3xxxxx))
#         self.wait(0.7)
#
#         nisko2xx = MathTex(r" B= 2+3(-\frac{5}{12})").scale(0.7).next_to(nisko, DOWN)
#         nisko2xx.shift(DOWN*0.5)
#         self.play(Transform(nisko2, nisko2xx))
#         self.wait(1)
#
#         nisko2xxx = MathTex(r" B= \frac{24}{12}-\frac{15}{12}").scale(0.7).next_to(nisko, DOWN)
#         nisko2xxx.shift(DOWN*0.5)
#         self.play(Transform(nisko2, nisko2xxx))
#         self.wait(1)
#
#         nisko2xxxx = MathTex(r" B= \frac{3}{4}").scale(0.7).next_to(nisko, DOWN)
#         nisko2xxxx.shift(DOWN*0.5)
#         self.play(Transform(nisko2, nisko2xxxx))
#         self.wait(1)
#
#         niskoxx = MathTex(r" C = \frac{5}{12}").scale(0.7)
#         niskoxx.shift(LEFT*5)
#         self.play(Transform(nisko, niskoxx))
#         self.wait(1)
#
#
#         przyklad1234567 = MathTex(r" =\frac{-\frac{5}{12}x + \frac{3}{4}}{x^2-3} + \frac{\frac{5}{12}}{x-3}").scale(0.7).next_to(przyklad12, RIGHT)
#         self.play(Transform(przyklad123, przyklad1234567))
#         self.wait(1)
#
#
#         wkoncurozwijamy = MathTex(r"= -\frac{5}{12} \int \frac{x}{x^2+3} dx + \frac{3}{4} \int \frac{dx}{x^2+3}+ \frac{5}{12} \int \frac{dx}{x-3}").scale(0.7).next_to(przyklad1, RIGHT)
#         self.play(Write(wkoncurozwijamy))
#         self.wait(1)
#
#         self.play(FadeOut(nisko3), run_time = 0.2)
#         self.play(FadeOut(nisko2), run_time = 0.2)
#         self.play(FadeOut(nisko), run_time = 0.2)
#         self.play(FadeOut(przyklad123), run_time = 0.2)
#         self.play(FadeOut(przyklad12), run_time = 0.2)
#         self.wait(2)
#
#         caleczk1 = MathTex(r" \int \frac{x}{x^2-3}dx ").scale(0.7)
#         caleczk1.shift(LEFT*5)
#         self.play(Write(caleczk1))
#         self.wait(1)
#
#         rozwod = MathTex(r"(x^2-3)' = 2x").scale(0.7)
#         rozwod.shift(LEFT*5 + DOWN)
#         self.play(Write(rozwod))
#         self.wait(1)
#
#         caleczk2 = MathTex(r"=  \frac{1}{2} \int \frac{2x}{x^2-3}dx ").scale(0.7).next_to(caleczk1, RIGHT)
#         self.play(Write(caleczk2))
#         self.wait(1)
#
#
#         self.play(FadeOut(rozwod), run_time = 0.2)
#
#         nadolewzor = MathTex(r" \int \frac{f'(x)}{f(x)} dx = ln|f(x)| + C ", color=GOLD).scale(0.7).next_to(caleczk1, DOWN)
#         nadolewzor.shift(RIGHT*2)
#         self.play(Write(nadolewzor))
#         self.wait(2)
#
#         caleczk3 = MathTex(r" = \frac{1}{2} \ln|x^2-3| + C ").scale(0.7).next_to(caleczk2, RIGHT)
#         self.play(Write(caleczk3))
#         self.wait(1)
#
#         self.play(FadeOut(nadolewzor), run_time = 0.2)
#         self.play(FadeOut(caleczk2), run_time = 0.2)
#         self.play(caleczk3.animate.shift(LEFT * 2.5))
#         self.wait(2)
#
#         caleczkr = MathTex(r"\int \frac{dx}{x^2+3} = ").scale(0.7).next_to(caleczk1, DOWN)
#         self.wait(1)
#         self.play(Write(caleczkr))
#
#         wzoreczek = MathTex(r"\int \frac{dx}{(x-p)^2 + q} = \frac{1}{q} \arctan(\frac{x-p}{\sqrt{q}}) + C", color = GOLD).scale(0.7)
#         wzoreczek.shift(DOWN*2+ LEFT*3)
#         self.play(Write(wzoreczek))
#         self.wait(2)
#
#         caleczkrr = MathTex(r" \frac{1}{3} \arctan(\frac{x}{\sqrt{3}}) + C ").scale(0.7).next_to(caleczkr, RIGHT)
#         self.wait(1)
#         self.play(Write(caleczkrr))
#
#         self.play(FadeOut(wzoreczek), run_time = 0.2)
#         self.wait(1)
#
#         vertez = MathTex(r" \int \frac{dx}{x-3} = ").scale(0.7).next_to(caleczkr, DOWN)
#         self.play(Write(vertez))
#         self.wait(2)
#
#         linij1= MathTex(r" \int \frac{dx}{ax+b} = \frac{1}{a}\ln |ax+b| +C ", color = GOLD).scale(0.75)
#         linij1.shift(LEFT *3 + UP*1)
#         self.play(Create(linij1), run_time = 1)
#         self.wait(2)
#
#         vertez2 = MathTex(r" \ln |x-3| + C ").scale(0.7).next_to(vertez,RIGHT)
#         self.play(Write(vertez2))
#         self.wait(2)
#
#         self.play(FadeOut(linij1), run_time=0.5)
#         self.wait(2)
#
#         nowosci = MathTex(r"= -\frac{5}{24} \ln|x^2-3| + \frac{1}{4} \arctan \frac{x}{\sqrt{3}} + \frac{5}{12} \ln |x-3| + C ", color = GOLD).scale(0.7).next_to(przyklad1, DOWN)
#         nowosci.shift(RIGHT*2)
#         self.play(Write(nowosci))
#         self.wait(2)
# Out:
# <video src="media/jupyter/tojeszczeniekoniec@2023-11-05@09-32-33.mp4" controls autoplay loop style="max-width: 60%;"  >
#       Your browser does not support the <code>video</code> element.
#     </video>

# %%
# %%manim -v WARNING bonus
#
# class bonus(Scene):
#     def construct(self):
#
#         przyklad1 = MathTex(r" \int \frac{dx}{x^4-11x^3+41x^2-61x+30}").scale(0.7)
#         przyklad1.shift(LEFT*4)
#         self.play(Write(przyklad1))
#         self.wait(1)
#
#         przyklad2 = MathTex(r"=  \int \frac{dx}{(x-1)(x-2)(x-3)(x-5)}", color = GOLD).scale(0.7)
#         przyklad2.shift(RIGHT*2)
#         self.play(Write(przyklad2))
#         self.wait(1)
#
#
#         self.play(
#         przyklad1.animate.shift(UP * 2),
#         przyklad2.animate.shift(UP * 2)
#         )
#         self.wait(2)
#
#         przykladt1 = MathTex(r" \int \frac{x^5+x^4-7x^3+2x}{x^2+1}dx").scale(0.7)
#         przykladt1.shift(LEFT*4+DOWN)
#         self.play(Write(przykladt1))
#         self.wait(1)
#
#         przykladt2 = MathTex(r"=  \int x^3+x^2-8x-1 +\frac{10x-1}{x^2+1} dx", color = GOLD).scale(0.7).next_to(przykladt1, RIGHT)
#         self.play(Write(przykladt2))
#         self.wait(1)
# Out:
# <video src="media/jupyter/bonus@2023-11-05@09-22-35.mp4" controls autoplay loop style="max-width: 60%;"  >
#       Your browser does not support the <code>video</code> element.
#     </video>
