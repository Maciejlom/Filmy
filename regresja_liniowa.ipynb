# %%
from manim import *
# Out:
# Manim Community v0.17.3

# %%
# %%manim -v WARNING czesc1
# class czesc1(Scene):
#     def construct(self):
#
#         linij1 =  Tex("Popyt na mleko migdałowe (w tys. litrów) w zależności od cen (w zł/l) kształtuje sie nastepujaco: ", font_size = 32, color= GOLD).move_to(UP*3.5+LEFT*2)
#         linij2 =  Tex("a. Oszacuj parametry funkcji liniowej zależności ceny od popytu ", font_size = 32, color= GOLD).move_to(UP*1.5+LEFT*2)
#         linij3 =  Tex("b. Jaki bedzie popyt na mleko, jeżeli 1 litr bedzie kosztował 4,0 zł ", font_size = 32, color= GOLD).move_to(DOWN*2.5+LEFT*2)
#         wzor1 = MathTex(r" C(p) = a \cdot p + b", font_size = 32).move_to(UP*0.5+LEFT*5)
#         wzor2 = MathTex(r" a = \frac{\sum (c_{i} - \bar{c}) \cdot (p - \bar{p})}{\sum (p_{i} - \bar{p})^2} ", font_size = 32).move_to(DOWN*0.5+LEFT*4.25)
#         wzor3 = MathTex(r" b = \bar{c} - a \cdot \bar{p} ", font_size = 32).move_to(DOWN*1.5 + LEFT*5)
#         wzor4 = MathTex(r" \bar{p}  = ", font_size = 32).move_to(UP*0.5+RIGHT)
#         wzor5 = MathTex(r" \frac{3,4 + 3,8 + 4,1 + 2,4 + 1,9 + 3,0}{6}", font_size = 32).next_to(wzor4, RIGHT)
#         wzor6 = MathTex(r" 3,1", font_size = 32).next_to(wzor4, RIGHT)
#         wzor7 = MathTex(r" \bar{c}  = ", font_size = 32).move_to(DOWN*0.5+RIGHT)
#         wzor8 = MathTex(r" \frac{1,6 + 1,4 + 1,2+ 2,1 + 2,9 + 2,2}{6}", font_size = 32).next_to(wzor7, RIGHT)
#         wzor9 = MathTex(r" 1,9", font_size = 32).next_to(wzor7, RIGHT)
#         wzor10 = MathTex(r" = \frac{-2,51}{3,52}", font_size = 32).next_to(wzor2, RIGHT)
#         wzor11 = MathTex(r" = -0,71", font_size = 32).next_to(wzor2, RIGHT)
#         wzor10.shift(DOWN*2)
#         wzor11.shift(DOWN*2)
#         wzor12 = MathTex(r" = 1,9 - (-0,71) \cdot 3,1", font_size = 32).next_to(wzor3, RIGHT)
#         wzor13 = MathTex(r" = 4,11", font_size = 32).next_to(wzor3, RIGHT)
#         wzor12.shift(DOWN+RIGHT*7)
#         wzor13.shift(DOWN+RIGHT*7)
#         wzor14 = MathTex(r" = -0,71 \cdot p + 4,11", font_size = 32).next_to(wzor1, RIGHT)
#         wzor14.shift(DOWN*2)
#
#         obliczenie = MathTex(r" C(4,0) = -0,71 \cdot 4,0 + 4,11", font_size = 32).move_to(DOWN*3.25+LEFT*4)
#         obliczenie2 = MathTex(r" = 1,26", font_size = 32).next_to(obliczenie, RIGHT)
#
#         obliczenie[0][13].set_color(GOLD)
#         obliczenie[0][14].set_color(GOLD)
#         obliczenie[0][15].set_color(GOLD)
#
#
#         s1 = (-6.5,2.75,0)
#         e1 = (1,2.75,0)
#         l1 = Line(s1,e1)
#
#         s2 = (-6.5,2.25,0)
#         e2 = (1,2.25,0)
#         l2 = Line(s2,e2)
#
#         s3 = (-6.5,1.75,0)
#         e3 = (1,1.75,0)
#         l3 = Line(s3,e3)
#
#         s4 = (-6.5,2.75,0)
#         e4 = (-6.5,1.75,0)
#         l4 = Line(s4,e4)
#
#         s5 = (-5,2.75,0)
#         e5 = (-5,1.75,0)
#         l5 = Line(s5,e5)
#
#         s6 = (-4,2.75,0)
#         e6 = (-4,1.75,0)
#         l6 = Line(s6,e6)
#
#         s7 = (-4,2.75,0)
#         e7 = (-4,1.75,0)
#         l7 = Line(s7,e7)
#
#         s8 = (-3,2.75,0)
#         e8 = (-3,1.75,0)
#         l8 = Line(s8,e8)
#
#         s9 = (-2,2.75,0)
#         e9 = (-2,1.75,0)
#         l9 = Line(s9,e9)
#
#         s10 = (-1,2.75,0)
#         e10 = (-1,1.75,0)
#         l10 = Line(s10,e10)
#
#         s11 = (0,2.75,0)
#         e11 = (0,1.75,0)
#         l11 = Line(s11,e11)
#
#         s12 = (1,2.75,0)
#         e12 = (1,1.75,0)
#         l12 = Line(s12,e12)
#
#         s13 = (-6.5,1.25,0)
#         e13 = (1,1.25,0)
#         l13 = Line(s13,e13)
#
#         s14 = (-6.5,0.75,0)
#         e14 = (1, 0.75,0)
#         l14 = Line(s14,e14)
#
#         s15 = (-6.5,0.25,0)
#         e15 = (1,0.25,0)
#         l15 = Line(s15,e15)
#
#         s155 = (-6.5,-0.25,0)
#         e155 = (1,-0.25,0)
#         l155 = Line(s155,e155)
#
#         s16 = (-6.5,1.75,0)
#         e16 = (-6.5,-0.25,0)
#         l16 = Line(s16,e16)
#
#         s17 = (-5,1.75,0)
#         e17 = (-5,-0.25,0)
#         l17 = Line(s17,e17)
#
#         s18 = (-4,1.75,0)
#         e18 = (-4,-0.25,0)
#         l18 = Line(s18,e18)
#
#         s19 = (-3,1.75,0)
#         e19 = (-3,-0.25,0)
#         l19 = Line(s19,e19)
#
#         s20 = (-2,1.75,0)
#         e20 = (-2,-0.25,0)
#         l20 = Line(s20,e20)
#
#         s21 = (-1,1.75,0)
#         e21 = (-1,-0.25,0)
#         l21 = Line(s21,e21)
#
#         s22 = (0,1.75,0)
#         e22 = (0,-0.25,0)
#         l22 = Line(s22,e22)
#
#         s23 = (1,1.75,0)
#         e23 = (1,-0.25,0)
#         l23 = Line(s23,e23)
#
#         s24 = (1,0.75,0)
#         e24 = (2,0.75,0)
#         l24 = Line(s24,e24)
#
#         s25 = (1,0.25,0)
#         e25 = (2,0.25,0)
#         l25 = Line(s25,e25)
#
#         s26 = (1,-0.25,0)
#         e26 = (2,-0.25,0)
#         l26 = Line(s26,e26)
#
#         s27 = (2,0.75,0)
#         e27 = (2,-0.25,0)
#         l27 = Line(s27,e27)
#
#         popyt = Tex("POPYT (p)", font_size = 24)
#         popyt.move_to([-5.75, 2.5, 0])
#
#         cena = Tex("CENA (c)", font_size = 24)
#         cena.move_to([-5.75, 2, 0])
#
#         pr = MathTex(r"p - \bar{p}", font_size = 24)
#         pr.move_to([-5.75, 1.5, 0])
#
#         cr = MathTex(r"c - \bar{c}", font_size = 24)
#         cr.move_to([-5.75, 1, 0])
#
#         crpr = MathTex(r"(c - \bar{c})(p - \bar{p})", font_size = 24)
#         crpr.move_to([-5.75, 0.5, 0])
#
#         prpr = MathTex(r"(p - \bar{p})^{2}", font_size = 24)
#         prpr.move_to([-5.75, 0, 0])
#
#         s = MathTex(r"\sum", font_size = 24)
#         s.move_to([1.5,1, 0])
#
#         s1 = MathTex(r"-2,51", font_size = 24)
#         s1.move_to([1.5,0.5, 0])
#
#         s2 = MathTex(r"3,52", font_size = 24)
#         s2.move_to([1.5,0, 0])
#
#
#
#
#         p1 = MathTex("3,4", font_size = 24)
#         p1.move_to([-4.5, 2.5, 0])
#
#         c1 = MathTex("1,6", font_size = 24)
#         c1.move_to([-4.5, 2, 0])
#
#         p2 = MathTex("3,8", font_size = 24)
#         p2.move_to([-3.5, 2.5, 0])
#
#         c2 = MathTex("1,4", font_size = 24)
#         c2.move_to([-3.5, 2, 0])
#
#         p3 = MathTex("4,1", font_size = 24)
#         p3.move_to([-2.5, 2.5, 0])
#
#         c3 = MathTex("1,2", font_size = 24)
#         c3.move_to([-2.5, 2, 0])
#
#         p4 = MathTex("2,4", font_size = 24)
#         p4.move_to([-1.5, 2.5, 0])
#
#         c4 = MathTex("2,1", font_size = 24)
#         c4.move_to([-1.5, 2, 0])
#
#         p5 = MathTex("1,9", font_size = 24)
#         p5.move_to([-0.5, 2.5, 0])
#
#         c5 = MathTex("2,9", font_size = 24)
#         c5.move_to([-0.5, 2, 0])
#
#         p6 = MathTex("3,0", font_size = 24)
#         p6.move_to([0.5, 2.5, 0])
#
#         c6 = MathTex("2,2", font_size = 24)
#         c6.move_to([0.5, 2, 0])
#
#         pr1 = MathTex("0,3", font_size = 24)
#         pr1.move_to([-4.5, 1.5, 0])
#
#         pr2 = MathTex("0,7", font_size = 24)
#         pr2.move_to([-3.5, 1.5, 0])
#
#         pr3 = MathTex("1", font_size = 24)
#         pr3.move_to([-2.5, 1.5, 0])
#
#         pr4 = MathTex("-0,7", font_size = 24)
#         pr4.move_to([-1.5, 1.5, 0])
#
#         pr5 = MathTex("-1,2", font_size = 24)
#         pr5.move_to([-0.5, 1.5, 0])
#
#         pr6 = MathTex("-0,1", font_size = 24)
#         pr6.move_to([0.5, 1.5, 0])
#
#         cr1 = MathTex("-0,3", font_size = 24)
#         cr1.move_to([-4.5, 1, 0])
#
#         cr2 = MathTex("-0,5", font_size = 24)
#         cr2.move_to([-3.5, 1, 0])
#
#         cr3 = MathTex("-0,7", font_size = 24)
#         cr3.move_to([-2.5, 1, 0])
#
#         cr4 = MathTex("0,2", font_size = 24)
#         cr4.move_to([-1.5, 1, 0])
#
#         cr5 = MathTex("1", font_size = 24)
#         cr5.move_to([-0.5, 1, 0])
#
#         cr6 = MathTex("0,3", font_size = 24)
#         cr6.move_to([0.5, 1, 0])
#
#         crpr1 = MathTex("-0,09", font_size = 24)
#         crpr1.move_to([-4.5, 0.5, 0])
#
#         crpr2 = MathTex("-0,35", font_size = 24)
#         crpr2.move_to([-3.5, 0.5, 0])
#
#         crpr3 = MathTex("-0,7", font_size = 24)
#         crpr3.move_to([-2.5, 0.5, 0])
#
#         crpr4 = MathTex("0,14", font_size = 24)
#         crpr4.move_to([-1.5, 0.5, 0])
#
#         crpr5 = MathTex("-1,2", font_size = 24)
#         crpr5.move_to([-0.5, 0.5, 0])
#
#         crpr6 = MathTex("-0,03", font_size = 24)
#         crpr6.move_to([0.5, 0.5, 0])
#
#         prpr1 = MathTex("0,09", font_size = 24)
#         prpr1.move_to([-4.5, 0, 0])
#
#         prpr2 = MathTex("0,49", font_size = 24)
#         prpr2.move_to([-3.5, 0, 0])
#
#         prpr3 = MathTex("1", font_size = 24)
#         prpr3.move_to([-2.5, 0, 0])
#
#         prpr4 = MathTex("0,49", font_size = 24)
#         prpr4.move_to([-1.5, 0, 0])
#
#         prpr5 = MathTex("1,44", font_size = 24)
#         prpr5.move_to([-0.5, 0, 0])
#
#         prpr6 = MathTex("0,01", font_size = 24)
#         prpr6.move_to([0.5, 0, 0])
#
#
#         self.play(Create(linij1), run_time = 1.5)
#         self.play(Create(l1), run_time = 0.1)
#         self.play(Create(l2), run_time = 0.1)
#         self.play(Create(l3), run_time = 0.1)
#         self.play(Create(l4), run_time = 0.1)
#         self.play(Create(l5), run_time = 0.1)
#         self.wait(0.1)
#         self.play(Create(popyt), run_time = 0.2)
#         self.play(Create(cena), run_time = 0.2)
#         self.play(Create(p1), run_time = 0.15)
#         self.play(Create(c1), run_time = 0.15)
#         self.play(Create(l6), run_time = 0.15)
#         self.play(Create(p2), run_time = 0.1)
#         self.play(Create(c2), run_time = 0.1)
#         self.play(Create(l7), run_time = 0.2)
#         self.wait(0.1)
#         self.play(Create(p3), run_time = 0.2)
#         self.wait(0.1)
#         self.play(Create(c3), run_time = 0.2)
#         self.wait(0.1)
#         self.play(Create(l8), run_time = 0.2)
#         self.wait(0.1)
#         self.play(Create(p4), run_time = 0.2)
#         self.wait(0.1)
#         self.play(Create(c4), run_time = 0.2)
#         self.wait(0.1)
#         self.play(Create(l9), run_time = 0.2)
#         self.wait(0.1)
#         self.play(Create(p5), run_time = 0.2)
#         self.wait(0.1)
#         self.play(Create(c5), run_time = 0.2)
#         self.wait(0.1)
#         self.play(Create(l10), run_time = 0.2)
#         self.wait(0.1)
#         self.play(Create(p6), run_time = 0.2)
#         self.wait(0.1)
#         self.play(Create(c6), run_time = 0.2)
#         self.wait(0.1)
#         self.play(Create(l11), Create(l12), run_time = 0.2)
#         self.wait(1)
#         self.play(Create(linij2))
#         self.wait(1)
#         self.play(Create(wzor1))
#         self.wait(4)
#         self.play(Create(wzor2))
#         self.play(Create(wzor3))
#         self.wait(7)
#         self.play(
#             p1.animate.set_color(RED),
#             p2.animate.set_color(RED),
#             p3.animate.set_color(RED),
#             p4.animate.set_color(RED),
#             p5.animate.set_color(RED),
#             p6.animate.set_color(RED),
#             )
#         self.wait(3)
#         self.play(Create(wzor4), run_time = 0.25)
#         self.wait(1.2)
#         self.play(Create(wzor5), run_time = 1)
#         self.wait(0.2)
#         self.play(Transform(wzor5, wzor6), run_time = 1)
#         self.wait(0.2)
#         self.play(
#             p1.animate.set_color(WHITE),
#             p2.animate.set_color(WHITE),
#             p3.animate.set_color(WHITE),
#             p4.animate.set_color(WHITE),
#             p5.animate.set_color(WHITE),
#             p6.animate.set_color(WHITE),
#             run_time = 0.5
#             )
#         self.wait(4)
#         self.play(
#             c1.animate.set_color(RED),
#             c2.animate.set_color(RED),
#             c3.animate.set_color(RED),
#             c4.animate.set_color(RED),
#             c5.animate.set_color(RED),
#             c6.animate.set_color(RED),
#             run_time = 0.5
#             )
#         self.wait(0.2)
#         self.play(Create(wzor7), run_time = 0.25)
#         self.play(Create(wzor8), run_time = 1.5)
#         self.wait(0.4)
#         self.play(Transform(wzor8, wzor9), run_time = 1)
#         self.wait(0.3)
#         self.play(
#             c1.animate.set_color(WHITE),
#             c2.animate.set_color(WHITE),
#             c3.animate.set_color(WHITE),
#             c4.animate.set_color(WHITE),
#             c5.animate.set_color(WHITE),
#             c6.animate.set_color(WHITE),
#             run_time = 0.2
#             )
#         self.wait(0.5)
#         self.play(
#             linij2.animate.shift(DOWN*2),
#             wzor1.animate.shift(DOWN*2),
#             wzor2.animate.shift(DOWN*2),
#             wzor3.animate.shift(DOWN*2),
#             wzor4.animate.shift(DOWN*2),
#             wzor5.animate.shift(DOWN*2),
#             wzor7.animate.shift(DOWN*2),
#             wzor8.animate.shift(DOWN*2)
#                     )
#
#         self.play(Create(l13), Create(l14), Create(l15), Create(l155))
#         self.wait(3)
#         self.play(
#             Create(l16), Create(l17), Create(l18), Create(l19),
#             Create(l20), Create(l21), Create(l22), Create(l23)
#         )
#         self.play(Create(pr))
#         self.wait(2)
#         self.play(
#             p1.animate.set_color(RED),
#             wzor4.animate.set_color(RED),
#             wzor5.animate.set_color(RED),
#                 )
#         self.play(Create(pr1), run_time = 0.7)
#         self.play(
#             p1.animate.set_color(WHITE),
#             p2.animate.set_color(RED),
#                 )
#         self.play(Create(pr2), run_time = 0.7)
#         self.play(
#             p2.animate.set_color(WHITE),
#             p3.animate.set_color(RED),
#                 )
#         self.play(Create(pr3), run_time = 0.7)
#         self.play(
#             p3.animate.set_color(WHITE),
#             p2.animate.set_color(WHITE),
#             wzor4.animate.set_color(WHITE),
#             wzor5.animate.set_color(WHITE),
#                 )
#         self.play(Create(pr4), run_time = 0.5)
#         self.play(Create(pr5), run_time = 0.5)
#         self.play(Create(pr6), run_time = 0.5)
#
#         self.play(Create(cr))
#         self.wait(1.5)
#
#         self.play(
#             c1.animate.set_color(RED),
#             wzor7.animate.set_color(RED),
#             wzor8.animate.set_color(RED),
#                 )
#         self.play(Create(cr1), run_time = 0.7)
#         self.play(
#             c1.animate.set_color(WHITE),
#             c2.animate.set_color(RED),
#                 )
#         self.play(Create(cr2), run_time = 0.7)
#         self.play(
#             c2.animate.set_color(WHITE),
#             c3.animate.set_color(RED),
#                 )
#         self.play(Create(cr3), run_time = 0.7)
#         self.play(
#             c3.animate.set_color(WHITE),
#             c2.animate.set_color(WHITE),
#             wzor7.animate.set_color(WHITE),
#             wzor8.animate.set_color(WHITE),
#                 )
#         self.play(Create(cr4), run_time = 0.5)
#         self.play(Create(cr5), run_time = 0.5)
#         self.play(Create(cr6), run_time = 0.5)
#
#         self.play(Create(crpr))
#         self.play(
#             cr1.animate.set_color(RED),
#             pr1.animate.set_color(RED),
#                 )
#         self.wait(0.5)
#         self.play(Create(crpr1), run_time = 0.4)
#         self.play(
#             cr2.animate.set_color(RED),
#             pr2.animate.set_color(RED),
#             cr1.animate.set_color(WHITE),
#             pr1.animate.set_color(WHITE),
#                 )
#         self.play(Create(crpr2), run_time = 0.4)
#         self.play(
#             cr3.animate.set_color(RED),
#             pr3.animate.set_color(RED),
#             cr2.animate.set_color(WHITE),
#             pr2.animate.set_color(WHITE),
#                 )
#         self.play(Create(crpr3), run_time = 0.4)
#         self.play(
#             cr3.animate.set_color(WHITE),
#             pr3.animate.set_color(WHITE))
#         self.play(Create(crpr4), run_time = 0.4)
#         self.play(Create(crpr5), run_time = 0.4)
#         self.play(Create(crpr6), run_time = 0.4)
#         self.play(Create(prpr))
#
#
#         self.wait(0.5)
#         self.play(pr1.animate.set_color(RED))
#         self.play(Create(prpr1), run_time = 0.4)
#         self.play(pr2.animate.set_color(RED), pr1.animate.set_color(WHITE))
#         self.play(Create(prpr2), run_time = 0.4)
#         self.play(pr3.animate.set_color(RED), pr2.animate.set_color(WHITE))
#         self.play(Create(prpr3), run_time = 0.4)
#         self.play(pr2.animate.set_color(WHITE), pr3.animate.set_color(WHITE))
#         self.play(Create(prpr4), run_time = 0.4)
#         self.play(Create(prpr5), run_time = 0.4)
#         self.play(Create(prpr6), run_time = 0.4)
#
#         self.wait(2.5)
#
#         self.play(Create(l24), Create(l25), Create(l26), Create(l27))
#
#         self.play(Create(s))
#         self.wait(3)
#         self.play(Create(s1))
#         self.wait(1.5)
#         self.play(Create(s2))
#         self.wait()
#         self.play(
#             wzor4.animate.shift(UP*4+RIGHT*3),
#             wzor5.animate.shift(UP*4+RIGHT*3),
#             wzor7.animate.shift(UP*4+RIGHT*3),
#             wzor8.animate.shift(UP*4+RIGHT*3)
#             )
#         self.play(Create(wzor10))
#         self.play(Transform(wzor10, wzor11))
#         self.wait()
#         self.play(wzor3.animate.shift(UP+RIGHT*7))
#         self.wait()
#         self.play(Create(wzor12))
#         self.play(Transform(wzor12, wzor13))
#         self.wait()
#         self.play(wzor2.animate.set_color(GREY), wzor3.animate.set_color(GREY))
#         self.wait()
#         self.play(Create(wzor14))
#         self.wait()
#         self.wait(5)
#         self.play(
#             FadeOut(wzor2),
#             FadeOut(wzor3),
#             FadeOut(wzor4),
#             FadeOut(wzor5),
#             FadeOut(wzor6),
#             FadeOut(wzor7),
#             FadeOut(wzor8),
#             FadeOut(wzor9),
#             FadeOut(wzor10),
#             FadeOut(wzor11),
#             FadeOut(wzor12),
#             FadeOut(wzor13)
#             )
#         self.play(Create(linij3))
#         self.wait()
#         self.play(Create(obliczenie))
#         self.wait()
#         self.play(Create(obliczenie2))
#         self.wait()
#
#
#
#
#         self.wait(16)
# Out:
# <video src="media/jupyter/czesc1@2024-02-08@16-27-03.mp4" controls autoplay loop style="max-width: 60%;"  >
#       Your browser does not support the <code>video</code> element.
#     </video>

# %%
# %%manim -v WARNING introq
#
# class introq(Scene):
#     def construct(self):
#
#         circle_outline = Circle(color=GOLD, fill_opacity=0, radius=2.5)
#         ax = Axes(
#             x_range=[0,6, 1],
#             y_range=[0,6,1],
#             x_length=6,
#             y_length=6,
#             axis_config={"include_numbers": False, "include_ticks": False,  "font_size": 16, 'tip_shape': StealthTip},
#             x_axis_config=None,
#             y_axis_config=None, tips=True)
#         ax.move_to(circle_outline.get_center()).scale(0.4)
#
#         labels = ax.get_axis_labels(
#             Tex("x").scale(0.45),
#             Text("y").scale(0.25)
#         )
#         p = ValueTracker(0)
#         q = ValueTracker(0)
#         def qf(x):
#             return   2 * x +1
#
#         k1 = ax.c2p(0, 0.7)
#         kr1 = Dot(k1, color = RED)
#
#         k2 = ax.c2p(0.25, 2.2)
#         kr2 = Dot(k2, color = RED)
#
#         k3 = ax.c2p(1, 1.6)
#         kr3 = Dot(k3, color = RED)
#
#         k4 = ax.c2p(1.3, 4.8)
#         kr4 = Dot(k4, color = RED)
#
#         k5 = ax.c2p(2, 4.1)
#         kr5 = Dot(k5, color = RED)
#
#         plot = ax.plot(qf, x_range=[0, 3, 0.01], color=GREEN)
#
#         napisduzy = Tex("Regresja liniowa").shift(UP*3)
#         napis1 = MathTex(r" Y = a \cdot X + b")
#
#
#         napis1.move_to(circle_outline.get_center())
#
#         self.add(napisduzy)
#         self.play(Write(circle_outline), run_time = 0.4)
#         self.play(Write(napis1), run_time = 0.4)
#         self.wait()
#         self.play(Transform(napis1, ax), run_time = 0.4)
#         self.play(Create(labels), Create(kr1), Create(kr2), Create(kr3), Create(kr4), Create(kr5), run_time = 1.25)
#         self.wait()
#         self.play(Create(plot))
#         self.wait(2)
# Out:
# <video src="media/jupyter/introq@2024-02-08@14-37-24.mp4" controls autoplay loop style="max-width: 60%;"  >
#       Your browser does not support the <code>video</code> element.
#     </video>
